# %% [markdown]
# | فیلد | توضیح |
# |---|---|
# | `column_name` | نام ستون |
# | `business_meaning` | معنای کسب‌وکاری |
# | `raw_dtype` | نوع داده خام |
# | `expected_dtype` | نوع داده مورد انتظار |
# | `unit` | ریال، تومان، متر، سال و غیره |
# | `allowed_values` | دامنه یا مقادیر مجاز |
# | `missing_meaning` | معنای Missing |
# | `cleaning_rule` | قاعده پاک‌سازی |
# | `quality_risk` | ریسک احتمالی |
# | `owner` | مسئول بررسی |

# %% [markdown]
# | `column_name` | `business_meaning` | `raw_dtype` | `expected_dtype` | `unit` | `allowed_values` | `missing_meaning` | `cleaning_rule` | `quality_risk` | `owner` |
# |---|---|---|---|---|---|---|---|---|---|
# |cat2_slug|دسته‌بندی اصلی آگهی|object|category|---|'temporary-rent', 'residential-sell', 'residential-rent', 'commercial-rent', 'commercial-sell', 'real-estate-services'|---|---|---|---|
# |cat3_slug|زیر‌دسته|object|category|---|---|---|---|---|---|
# |city_slug|شهر ملک|object|category|---|---|---|---|---|---|
# |neighborhood_slug|محله ملک|object|category|---|---|---|---|---|---|
# |created_at_month|ماه ایجاد آگهی|object|datetime|تاریخ شمسی|---|---|---|---|---|
# |user_type|نوع کاربر منتشرکننده آگهی|object|category|---|'شخصی', 'مشاور املاک'|---|---|---|---|
# |description|توضیحات کامل ملک|object|object|---|---|---|---|---|---|
# |title|عنوان آگهی|object|object|---|---|---|---|---|---|
# |rent_mode|روش تعیین اجاره|object|category|---|'مقطوع', 'مجانی', 'توافقی'|---|---|---|---|
# |rent_value|مبلغ اجاره|float64|float64|تومان|---|---|---|---|---|
# |rent_to_single|امکان اجاره به فرد مجرد|float64|boolean|---|True/Flase/None|---|---|---|---|
# |rent_type|نوع اجاره|object|category|---|'rent_credit', 'full_credit'|---|---|---|---|
# |price_mode|روش تعیین قیمت فروش|object|category|---|---|---|---|---|---|
# |price_value|مبلغ فروش|float64|float64|تومان|---|---|---|---|---|
# |credit_mode|روش تعیین رهن|object|category|---|---|---|---|---|---|
# |credit_value|مبلغ رهن|float64|float64|تومان|---|---|---|---|---|
# |rent_credit_transform|امکان تبدیل رهن و اجاره|object|boolean|---|True/Flase/None|---|---|---|---|
# |transformable_price|قابل تبدیل بودن قیمت|object|boolean|---|---|---|---|---|---|
# |transformable_credit|مبلغ رهن قابل تبدیل|float64|float64|تومان|---|---|---|---|---|
# |transformed_credit|مبلغ رهن پس از تبدیل|float64|float64|تومان|---|---|---|---|---|
# |transformable_rent|اجاره قابل تبدیل|float64|float64|تومان|---|---|---|---|---|
# |transformed_rent|اجاره پس از تبدیل|float64|float64|---|---|---|---|---|---|
# |land_size|مساحت زمین|float64|Int32|متر مربع|---|---|---|---|---|
# |building_size|زیربنای ملک|float64|متر مربع|---|---|---|---|---|---|
# |deed_type|نوع سند ملک|object|category|---|'single_page', 'other', 'written_agreement', 'multi_page'|---|---|---|---|
# |has_business_deed|وجود سند تجاری|object|boolean|---|True/Flase/None|---|---|---|---|
# |floor|طبقه واحد|object|Int8|---|(-1,31)|---|---|---|---|
# |rooms_count|تعداد اتاق خواب|object|Int8|---|(0,5)|---|---|---|---|
# |total_floors_count|تعداد کل طبقات ساختمان|object|Int8|---|(2,31)|---|---|---|---|
# |unit_per_floor|تعداد واحد در هر طبقه|object|Int8|---|(1,9)|---|---|---|---|
# |has_balcony|وجود بالکن|object|boolean|---|True/Flase/None|---|---|---|---|
# |has_elevator|وجود آسانسور|object|boolean|---|True/Flase/None|---|---|---|---|
# |has_warehouse|وجود انباری|object|boolean|---|True/Flase/None|---|---|---|---|
# |has_parking|وجود پارکینگ|object|boolean|---|True/Flase/None|---|---|---|---|
# |construction_year|سال ساخت|object|Int16|سال|(1370-1403)|---|---|---|---|
# |is_rebuilt|بازسازی‌شده بودن ملک|object|boolean|---|True/Flase/None|---|---|---|---|
# |has_water|دسترسی به آب|object|boolean|---|True/Flase/None|---|---|---|---|
# |has_warm_water_provider|سیستم تأمین آب گرم|object|category|---|'package', 'powerhouse', 'water_heater'|---|---|---|---|
# |has_electricity|دسترسی به برق|object|boolean|---|True/Flase/None|---|---|---|---|
# |has_gas|دسترسی به گاز|object|boolean|---|True/Flase/None|---|---|---|---|
# |has_heating_system|سیستم گرمایشی|object|category|---|'duct_split', 'fan_coil', 'fireplace', 'floor_heating', 'heater', 'shoofaj', 'split'|---|---|---|---|
# |has_cooling_system|سیستم سرمایشی|object|category|---|'air_conditioner', 'duct_split', 'fan_coil', 'split', 'water_cooler'|---|---|---|---|
# |has_restroom|نوع سرویس بهداشتی|object|category|---|'seat', 'squat', 'squat_seat'|---|---|---|---|
# |has_security_guard|وجود نگهبان|object|boolean|---|True/Flase/None|---|---|---|---|
# |has_barbecue|وجود باربیکیو|object|boolean|---|True/Flase/None|---|---|---|---|
# |has_pool|وجود استخر|object|boolean|---|---|True/Flase/None|---|---|---|
# |has_jacuzzi|وجود جکوزی|object|boolean|---|True/Flase/None|---|---|---|---|
# |has_sauna|وجود سونا|object|boolean|---|True/Flase/None|---|---|---|---|
# |floor_material|جنس کف|object|category|---|'carpet', 'ceramic', 'floor_covering', 'laminate_parquet', 'mosaic', 'stone', 'unselect', 'wood_parquet'|---|---|---|---|
# |property_type|---|object|category|---|[NaN, 'jungle', 'other', 'beach', 'jungle-mountain', 'mountain']|---|---|---|---|
# |regular_person_capacity|ظرفیت معمول افراد|float64|Int8|نفر|min: 1 max: 50|---|---|---|---|
# |extra_person_capacity|ظرفیت نفر اضافه|object|Int8|نفر|min: 0 max: 31|---|---|---|---|
# |cost_per_extra_person|هزینه هر نفر اضافه|float64|float64|تومان|---|---|---|---|---|
# |rent_price_on_regular_days|اجاره در روزهای عادی|float64|float64|تومان|---|---|---|---|---|
# |rent_price_on_special_days|اجاره در روزهای خاص|float64|float64|تومان|---|---|---|---|---|
# |rent_price_at_weekends|اجاره در آخر هفته|float64|float64|تومان|min: 0.0 max: 200250300400450.0|---|---|---|---|
# |location_latitude|عرض جغرافیایی ملک|float64|float64|---|min: 23.62647819519043 max: 40.358055114746094|---|---|---|---|
# |location_longitude|طول جغرافیایی ملک|float64|float64|---|min: 40.16236877441406 max: 74.5116195678711|---|---|---|---|
# |location_radius|شعاع دقت موقعیت مکانی|float64|Int16|متر|0,300,500|---|---|---|---|
